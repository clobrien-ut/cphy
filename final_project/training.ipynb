# %% [markdown]
# # Conditional Variational Autoencoder
#
# ## Overview
#
# This notebook implements the CVAE architecture we used for our generative model simulation. We used PyTorch for the model and the basic Tensor operations.

# %%
! pip install torch
# Out:
# Collecting torch
#   Obtaining dependency information for torch from https://files.pythonhosted.org/packages/25/5d/22b4d5d2183e03f197a5e6b2721bb8f7a3e92b4947b16b70316c1e3771f3/torch-2.1.1-cp310-none-macosx_11_0_arm64.whl.metadata
#   Downloading torch-2.1.1-cp310-none-macosx_11_0_arm64.whl.metadata (25 kB)
# Collecting filelock (from torch)
#   Obtaining dependency information for filelock from https://files.pythonhosted.org/packages/81/54/84d42a0bee35edba99dee7b59a8d4970eccdd44b99fe728ed912106fc781/filelock-3.13.1-py3-none-any.whl.metadata
#   Downloading filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch) (4.7.1)
# Collecting sympy (from torch)
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 8.3 MB/s eta 0:00:0000:0100:01m
# Collecting networkx (from torch)
#   Obtaining dependency information for networkx from https://files.pythonhosted.org/packages/d5/f0/8fbc882ca80cf077f1b246c0e3c3465f7f415439bdea6b899f6b19f61f70/networkx-3.2.1-py3-none-any.whl.metadata
#   Downloading networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting jinja2 (from torch)
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 3.0 MB/s eta 0:00:00a 0:00:01
# Collecting fsspec (from torch)
#   Obtaining dependency information for fsspec from https://files.pythonhosted.org/packages/96/0e/2be9b5a2e3f736577e749bbdf27a1e7e965041e1c908d49dedf56eeb2b8a/fsspec-2023.12.1-py3-none-any.whl.metadata
#   Downloading fsspec-2023.12.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Obtaining dependency information for MarkupSafe>=2.0 from https://files.pythonhosted.org/packages/20/1d/713d443799d935f4d26a4f1510c9e61b1d288592fb869845e5cc92a1e055/MarkupSafe-2.1.3-cp310-cp310-macosx_10_9_universal2.whl.metadata
#   Downloading MarkupSafe-2.1.3-cp310-cp310-macosx_10_9_universal2.whl.metadata (3.0 kB)
# Collecting mpmath>=0.19 (from sympy->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 8.5 MB/s eta 0:00:00a 0:00:01
# Downloading torch-2.1.1-cp310-none-macosx_11_0_arm64.whl (59.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 MB 8.2 MB/s eta 0:00:0000:0100:01m
# Downloading filelock-3.13.1-py3-none-any.whl (11 kB)
# Downloading fsspec-2023.12.1-py3-none-any.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.9/168.9 kB 4.0 MB/s eta 0:00:00ta 0:00:01
# Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 6.2 MB/s eta 0:00:0000:0100:01m
# Downloading MarkupSafe-2.1.3-cp310-cp310-macosx_10_9_universal2.whl (17 kB)
# Installing collected packages: mpmath, sympy, networkx, MarkupSafe, fsspec, filelock, jinja2, torch
# Successfully installed MarkupSafe-2.1.3 filelock-3.13.1 fsspec-2023.12.1 jinja2-3.1.2 mpmath-1.3.0 networkx-3.2.1 sympy-1.12 torch-2.1.1
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## CVAE Implementation
#
# The class `CVAE3` is our implementation of the conditional variational autoencoder. It takes as input a set of data and a set of conditions and returns a reconstructed set of data in the same space as the original input data. As in the vanilla VAE architecture, the encoder and decoder allow mappings into and from the latent space, respectively.

# %%
# CVAE Model

import torch
from torch import nn, optim
import torch.nn.functional as F

class CVAE3(nn.Module):
    '''
    The CVAE3 class, which implements our model.
    '''
    def __init__(self, cond_dim=100, input_dim=1000, hidden_dim=100, latent_space_dim=2):
        '''
        Constructs a CVAE3 object.
    
        Parameters
        ----------------
        cond_dim : int
            The dimension of the conditions space (flattened).
        input_dim : int
            The dimension of the input or data space (flattened).
        hidden_dim : int
            The dimension of the hidden layers in the encoder and decoder layers
        latent_space_dim : int
            The dimension of the latent space (without accounting for the added conditions). Default value is 2 for a variational autoencoder.
        '''
        super(CVAE3, self).__init__()
        
        # initialize parameters
        self.cond_dim = cond_dim
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.latent_space_dim = latent_space_dim
        
        # Encoder layers
        self.e1  = nn.Linear(input_dim + cond_dim, hidden_dim)
        self.e2 = nn.Linear(hidden_dim, latent_space_dim) # mu
        self.e3 = nn.Linear(hidden_dim, latent_space_dim) # sigma

        # Decoder layers
        self.d1 = nn.Linear(latent_space_dim + cond_dim, hidden_dim)
        self.d2 = nn.Linear(hidden_dim, input_dim)

        # Acivation function
        self.activation = nn.Sigmoid()
        
    def encode(self, x, c):
        '''
        Encodes the data and conditions, returning the mean and std deviation for the distribution.
    
        Parameters
        ----------------
        x : PyTorch Tensor
            The data input to the model.
        c : PyTorch Tensor
            The conditions input to the model.

        Returns
        ----------------
        mu, sigma : int    
        '''
        inputs = torch.cat([x, c])
        h1 = self.activation(self.e1(inputs))
        mu = self.e2(h1)
        sigma = self.e3(h1)
        return mu, sigma

    def reparameterize(self, mu, logvar):
        '''
        Implements the reparametrization trick commonly used in VAE implementations.
    
        Parameters
        ----------------
        mu : int
            The mean of the distribution
        logvar : int
            The log of the variance.

        Returns
        ----------------
        reparametrized value : int   
        '''
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return mu + eps*std

    def decode(self, z, c):
        '''
        Decodes the information contained in the latent space, returning the reconstructed data.
    
        Parameters
        ----------------
        z : PyTorch Tensor
            The latent space tensor.
        c : PyTorch Tensor
            The conditions input to the model.

        Returns
        ----------------
        decoded data : PyTorch Tensor    
        '''
        inputs = torch.cat([z, c])
        h3 = self.activation(self.d1(inputs))
        return self.activation(self.d2(h3))

    def forward(self, x, c):
        '''
        Apply the model to the data.
    
        Parameters
        ----------------
        x : PyTorch Tensor
            The data input to the model.
        c : PyTorch Tensor
            The conditions input to the model.

        Returns
        ----------------
        decoded data, mu, sigma : PyTorch Tensor, int, int    
        '''
        mu, logvar = self.encode(x, c)
        z = self.reparameterize(mu, logvar)
        return self.decode(z, c), mu, logvar

# %% [markdown]
# ## Loading the Data Into a Data Frame

# %%
# load the dataframe from 'input_data_frame.csv'

import pandas as pd

df = pd.read_csv('pmt800_dataFrame_5_files.csv', index_col=[0])

# set NaN in dataframe to zero
df = df.fillna(0)

# print the resulting dataframe to check for mistakes
df
# Out:
#        run  evt  channel  hit     startTime  nSamples  count  \
# 77       0    1      800  0.0  1.515198e+07        94    1.0
# 192      0    2      800  0.0  2.712405e+08       104    1.0
# 310      0    3      800  0.0  4.966643e+08       114    1.0
# 424      0    4      800  0.0  7.697597e+08        96    1.0
# 638      0    6      800  0.0  1.094312e+09        96    1.0
# ...    ...  ...      ...  ...           ...       ...    ...
# 29961    4   89      800  0.0  9.959707e+09        95    1.0
# 30083    4   91      800  0.0  1.035465e+10        90    1.0
# 30215    4   92      800  0.0  1.037607e+10        87    1.0
# 30306    4   93      800  0.0  1.044898e+10       100    1.0
# 30424    4   94      800  0.0  1.069707e+10        90    1.0
#
#        channelPhotonSum  sample000  sample001  ...  sample190  sample191  \
# 77                  2.0       7376       7372  ...       7389       7389
# 192                21.0       7372       7373  ...       7389       7389
# 310                16.0       7371       7373  ...       7389       7389
# 424                 6.0       7367       7373  ...       7389       7389
# 638                 4.0       7374       7374  ...       7389       7389
# ...                 ...        ...        ...  ...        ...        ...
# 29961               9.0       7368       7367  ...       7389       7389
# 30083               3.0       7373       7372  ...       7389       7389
# 30215               4.0       7377       7376  ...       7389       7389
# 30306              14.0       7373       7378  ...       7389       7389
# 30424               6.0       7370       7371  ...       7389       7389
#
#        sample192  sample193  sample194  sample195  sample196  sample197  \
# 77          7389       7389       7389       7389       7389       7389
# 192         7389       7389       7389       7389       7389       7389
# 310         7389       7389       7389       7389       7389       7389
# 424         7389       7389       7389       7389       7389       7389
# 638         7389       7389       7389       7389       7389       7389
# ...          ...        ...        ...        ...        ...        ...
# 29961       7389       7389       7389       7389       7389       7389
# 30083       7389       7389       7389       7389       7389       7389
# 30215       7389       7389       7389       7389       7389       7389
# 30306       7389       7389       7389       7389       7389       7389
# 30424       7389       7389       7389       7389       7389       7389
#
#        sample198  sample199
# 77          7389       7389
# 192         7389       7389
# 310         7389       7389
# 424         7389       7389
# 638         7389       7389
# ...          ...        ...
# 29961       7389       7389
# 30083       7389       7389
# 30215       7389       7389
# 30306       7389       7389
# 30424       7389       7389
#
# [242 rows x 208 columns]

# %%
# Create the Pytorch tensors containing the data in the dataframe

import numpy as np

# The conditions are the channelPhotonSum
df_cond = df.loc[:,'channelPhotonSum']
print(df_cond)

# The sample data are the DER response which we are trying to simulate
df_input = df.iloc[:,8:]
print(df_input)

c_tens = torch.from_numpy(df_cond.to_numpy())
print(c_tens.shape)

# For the input data, include a division by the baseline for the detector, which is a value of 7389.
# This will set the input data to a range 0 to 1 which can then be rescaled to 0 to 7389.
x_tens = torch.from_numpy(np.divide(df_input.to_numpy(),7389))
x_tens
# Out:
# 77        2.0
# 192      21.0
# 310      16.0
# 424       6.0
# 638       4.0
#          ...
# 29961     9.0
# 30083     3.0
# 30215     4.0
# 30306    14.0
# 30424     6.0
# Name: channelPhotonSum, Length: 242, dtype: float64
#        sample000  sample001  sample002  sample003  sample004  sample005  \
# 77          7376       7372       7372       7376       7370       7374
# 192         7372       7373       7375       7371       7378       7371
# 310         7371       7373       7374       7375       7380       7367
# 424         7367       7373       7374       7369       7372       7373
# 638         7374       7374       7375       7366       7367       7366
# ...          ...        ...        ...        ...        ...        ...
# 29961       7368       7367       7371       7369       7372       7371
# 30083       7373       7372       7377       7374       7370       7370
# 30215       7377       7376       7376       7371       7365       7376
# 30306       7373       7378       7368       7371       7374       7372
# 30424       7370       7371       7366       7371       7373       7373
#
#        sample006  sample007  sample008  sample009  ...  sample190  sample191  \
# 77          7372       7369       7373       7374  ...       7389       7389
# 192         7374       7371       7377       7374  ...       7389       7389
# 310         7377       7375       7372       7377  ...       7389       7389
# 424         7373       7371       7369       7368  ...       7389       7389
# 638         7369       7369       7375       7375  ...       7389       7389
# ...          ...        ...        ...        ...  ...        ...        ...
# 29961       7370       7376       7372       7374  ...       7389       7389
# 30083       7373       7370       7376       7375  ...       7389       7389
# 30215       7369       7374       7372       7371  ...       7389       7389
# 30306       7370       7371       7378       7370  ...       7389       7389
# 30424       7376       7369       7373       7376  ...       7389       7389
#
#        sample192  sample193  sample194  sample195  sample196  sample197  \
# 77          7389       7389       7389       7389       7389       7389
# 192         7389       7389       7389       7389       7389       7389
# 310         7389       7389       7389       7389       7389       7389
# 424         7389       7389       7389       7389       7389       7389
# 638         7389       7389       7389       7389       7389       7389
# ...          ...        ...        ...        ...        ...        ...
# 29961       7389       7389       7389       7389       7389       7389
# 30083       7389       7389       7389       7389       7389       7389
# 30215       7389       7389       7389       7389       7389       7389
# 30306       7389       7389       7389       7389       7389       7389
# 30424       7389       7389       7389       7389       7389       7389
#
#        sample198  sample199
# 77          7389       7389
# 192         7389       7389
# 310         7389       7389
# 424         7389       7389
# 638         7389       7389
# ...          ...        ...
# 29961       7389       7389
# 30083       7389       7389
# 30215       7389       7389
# 30306       7389       7389
# 30424       7389       7389
#
# [242 rows x 200 columns]
# torch.Size([242])
# tensor([[0.9982, 0.9977, 0.9977,  ..., 1.0000, 1.0000, 1.0000],
#         [0.9977, 0.9978, 0.9981,  ..., 1.0000, 1.0000, 1.0000],
#         [0.9976, 0.9978, 0.9980,  ..., 1.0000, 1.0000, 1.0000],
#         ...,
#         [0.9984, 0.9982, 0.9982,  ..., 1.0000, 1.0000, 1.0000],
#         [0.9978, 0.9985, 0.9972,  ..., 1.0000, 1.0000, 1.0000],
#         [0.9974, 0.9976, 0.9969,  ..., 1.0000, 1.0000, 1.0000]],
#        dtype=torch.float64)

# %% [markdown]
# ## Creating and Training the Model

# %%
# create the model (rows in the dataframe are individual events)

model = CVAE3(cond_dim=1, input_dim=x_tens.shape[0],hidden_dim=100, latent_space_dim=2)
print(model)
# Out:
# CVAE3(
#   (e1): Linear(in_features=243, out_features=100, bias=True)
#   (e2): Linear(in_features=100, out_features=2, bias=True)
#   (e3): Linear(in_features=100, out_features=2, bias=True)
#   (d1): Linear(in_features=3, out_features=100, bias=True)
#   (d2): Linear(in_features=100, out_features=242, bias=True)
#   (activation): Sigmoid()
# )

# %%
# Define the device for PyTorch for future use (if needed)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# loss function
def loss_function(recon_x, x, mu, logvar):
    '''
    The loss function for the training.

    Parameters
    ----------------
    recon_x : PyTorch Tensor
        The reconstructed data from the model.
    x : PyTorch Tensor
        The input data to the model.
    mu : int
        The mean from the VAE.
    logvar : int
        The logarithm of the variance from the VAE.

    Returns
    ----------------
    loss : int
        The loss for the VAE, which is a sum of the Kulback-Leibler Divergence loss (common to any VAE),
        and the mean squared error loss between the reconstructed data and the original input data.
    '''
    Recon_loss = F.mse_loss(recon_x, x)
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    print("Recon_loss = " + str(Recon_loss) + " and KLD_loss = " + str(KLD))
    return Recon_loss + KLD

# %%
# test training
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
def train(epochs, x_data, c_data, optimizer):
    model.train()    
    model.float()
    
    loss_file = open('loss_file_', 'w')
    for e in range(epochs):
        for i in range(x_data.shape[1]):
            x = x_data[:,i].float()
            c = torch.reshape(c_data[i],(1,)).float()
            
            x_prediction, mu, logvar = model(x, c)
            
            loss = loss_function(x_prediction, x, mu, logvar)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            loss_file.write("%s\n" % loss.item())
            
    loss_file.close()
    # save the model
    torch.save(model.state_dict(), 'model_weights.pth')

# %%
train(50, x_tens, c_tens, optimizer)
# Out:
# Recon_loss = tensor(0.0024, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.6004e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.8247e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.5080e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.0664e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0017, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.4869e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.2187e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.7849e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1027e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.9605e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.7551e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.2452e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.8892e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0018, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.8014e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0017, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.4506e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.0490e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.2338e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0020, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.1292e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1623e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.2850e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.5497e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0020, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.7188e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0017, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.6955e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.4506e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.8610e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0020, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.9009e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1921e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.4901e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.6359e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.5378e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0017, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.3709e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.1526e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0017, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.6194e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0017, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.1691e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0008, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.3447e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0009, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.2127e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0048, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.4240e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0090, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.4359e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0088, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.2195e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0078, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.0401e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0051, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.1184e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0044, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(0.0001, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0029, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.4373e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0022, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.5909e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0018, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(0.0002, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(0.0002, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(0.0001, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(0.0001, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0009, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.4492e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.7678e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.8144e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.5701e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.9025e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.8415e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.3064e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0021, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(0.0001, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0023, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.8367e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1295e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.6624e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.2858e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.2254e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.6159e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.4736e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0020, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1832e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0019, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.9938e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0022, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.4170e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1504e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.0222e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.6093e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.5855e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(9.0003e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.3048e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0018, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.7226e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(9.0897e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(9.1195e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.4240e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.7551e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0021, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.1095e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.2517e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.7817e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.3530e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.3975e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.5565e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.3709e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0020, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.2189e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0019, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.4991e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0019, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1772e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.3447e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0019, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.6226e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0019, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.3113e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0024, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.8179e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0017, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.7088e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0019, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.2187e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0018, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.9605e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.6028e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.4275e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0020, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.2352e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0021, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.6226e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.2815e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.0192e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.9802e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0018, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.4736e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.5332e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.4506e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.8014e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.7486e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.4603e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.9802e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0022, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.1360e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.5565e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(0.0002, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1921e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.3119e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.4571e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.6478e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.0678e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.1870e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.6865e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.5885e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.0499e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.3379e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0032, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.2333e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0018, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.8564e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.5408e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.9938e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0020, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.3276e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.3257e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.8060e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0023, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.3842e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.6123e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.9992e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.5896e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.1458e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.2040e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.3411e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.2219e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.5432e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.6958e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.7486e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.5497e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0017, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.7329e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0021, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.6584e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.3709e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.4305e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.1989e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.7486e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.2254e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.8380e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.4571e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.0312e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.0266e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0023, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.9968e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0022, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.2696e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.4603e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0022, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.5267e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0025, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.3181e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0017, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.9407e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.4140e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0018, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.3544e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.7784e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.7941e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.8610e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.4373e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.7486e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(0.0005, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.7353e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.4424e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0020, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.1425e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.3447e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0024, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.9504e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.9862e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1414e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.5123e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0019, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.3479e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.7486e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.2850e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.4603e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0017, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.9789e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1921e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.9968e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.7684e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.9073e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.8743e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.0632e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0019, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.6212e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.8876e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.8545e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.2398e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1921e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0019, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.5199e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1921e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.7486e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.6427e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0022, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.2590e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.7716e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.4603e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.5736e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.3053e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.9802e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0019, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(9.6560e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.8545e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1057e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.7220e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1921e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.7881e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.1458e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.3246e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.1888e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.2517e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.3975e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.9073e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.4107e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.0696e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.7583e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.3842e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(9.6560e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1027e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0018, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.4305e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.2219e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.1691e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.0729e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0019, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.7651e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.6955e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(9.2387e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.5497e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.8280e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.9407e-08, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.9605e-08, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.1590e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.2338e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.3447e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.6028e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.3081e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.6492e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0006, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.1526e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0009, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.0756e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0049, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.3048e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0094, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.9680e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0092, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.3598e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0080, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.2606e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0054, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.6267e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0046, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(0.0001, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0029, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.2346e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0022, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.3704e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0018, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(0.0002, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(0.0001, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(9.8735e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0009, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.9840e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0008, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.9485e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.9765e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0008, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.6952e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0007, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.0813e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0008, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.9889e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0009, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.7445e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0008, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.4227e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0021, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.1317e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0019, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.0607e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.6391e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.3395e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.0442e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0009, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.6234e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0009, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.8740e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.0312e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0017, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.3693e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.5286e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0020, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.1769e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.2189e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.6123e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.3246e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.5199e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.8545e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.9705e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.8805e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1206e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.9274e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.4703e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.4836e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.1095e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.2517e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.2452e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.3447e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.3379e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.2352e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.0398e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.5974e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0017, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.3679e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.5267e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.5565e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0019, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.0100e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0018, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.6028e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0021, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.5630e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.9472e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0018, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.3677e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.1691e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.9339e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.4506e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0017, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.3411e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.9802e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.7881e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(9.6262e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.9073e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.1458e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.7881e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.2219e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.0696e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.0466e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.5034e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(9.5367e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0017, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.6028e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.1723e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(0.0001, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.0133e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.2406e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.3603e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.5928e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.3392e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.4018e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.6017e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.2122e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.9504e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.8743e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0021, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.6581e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.0994e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(9.8050e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.0878e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0017, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1802e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.7478e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.1577e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0017, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.7684e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.6928e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.8071e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.8610e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1921e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.0068e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.3511e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.2187e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(9.1791e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.8358e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.3314e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.1526e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.4395e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.2070e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.0531e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.1127e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.9705e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.6689e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.8843e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.4405e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.9407e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.3081e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0013, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.7088e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0020, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.2262e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0017, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.3709e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.8179e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.3511e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0020, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.6524e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.4305e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.4438e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.2154e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(9.5665e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.5140e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.7583e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.0100e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.4901e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(0.0004, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.2187e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.4506e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.5332e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.3447e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0020, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.3113e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.7657e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.0192e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.2322e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.6657e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.7881e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.6492e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.6987e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.9222e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(9.2387e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.9073e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1921e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.5565e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.2650e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.6524e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.0341e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.6492e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.0201e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(9.4771e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.3644e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.5497e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.6294e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.4506e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.3644e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0021, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.8418e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.3842e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1325e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.2577e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0009, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.0669e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.9802e-08, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0015, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.4075e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.9605e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0016, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.8082e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0009, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.0962e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0009, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.9407e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.7881e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.2352e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0009, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.2517e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0011, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.0696e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(9.2387e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0008, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.0862e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0008, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.2517e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.2187e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0009, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.0742e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(9.8348e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0012, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1921e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0009, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.2254e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0009, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(9.1195e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(9.2387e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.9407e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0009, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.0531e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0010, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.0664e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0014, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.1393e-06, grad_fn=<MulBackward0>)
# ...
# Recon_loss = tensor(1.3985e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(0.0001, grad_fn=<MulBackward0>)
# Recon_loss = tensor(1.2905e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(0.0002, grad_fn=<MulBackward0>)
# Recon_loss = tensor(1.5440e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.9274e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(1.8354e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.6269e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(1.8369e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.9407e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(1.3571e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(0.0001, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.1489e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.8559e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(1.3030e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.4899e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(1.3969e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(9.2447e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(1.4149e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.9426e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(1.6496e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.9816e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.2786e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.2709e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(1.4080e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.8608e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(1.5029e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.4733e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(1.3001e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.1338e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(1.4375e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.6212e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(1.4337e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.8477e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(1.3951e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.2365e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.6093e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.3067e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.6473e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.1260e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.7634e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.8090e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(1.6845e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(0.0002, grad_fn=<MulBackward0>)
# Recon_loss = tensor(4.4500e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.3858e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.5027e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.2067e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(6.4153e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.4630e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.5870e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(9.6560e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.9242e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.9431e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.8273e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.7806e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(1.9448e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.2005e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(1.7977e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.0233e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(4.3223e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.9027e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(5.1012e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.6822e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.6640e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.8743e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.3000e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.4842e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.2294e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.4408e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(5.7033e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.6627e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.7372e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.7418e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.7121e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.2054e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.7243e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.7345e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.8045e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.6624e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.9265e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.5332e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.9898e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.4506e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(5.5579e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.7762e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.8811e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.8312e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.1493e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.1856e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.2127e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.3777e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.2665e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.1458e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.3519e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.1008e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.6939e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.7315e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.1125e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.5630e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.9036e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.3411e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.1333e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.6510e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.0593e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.0610e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.5424e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.6391e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.0256e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.2815e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(0.0001, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.7917e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(4.5120e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.7120e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.1021e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.1458e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.5157e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.7088e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(5.9940e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.7730e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.5461e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.7817e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.1940e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.7285e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(5.8288e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.3262e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.9344e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.4305e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.1388e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.1011e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.2870e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.5852e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.0944e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.8876e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.0326e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.0742e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.1382e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.2875e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.1025e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.6689e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.0778e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.5102e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.4980e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.4365e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.9063e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.5896e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.5587e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.5332e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(4.3526e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.8578e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(5.6205e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.0233e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.0210e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.8610e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.8740e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.4305e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.8155e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.2154e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.3610e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.7055e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.8547e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.9407e-08, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.6884e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.2485e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.9351e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.4703e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.9496e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.2883e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.9080e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.2187e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(9.7417e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1474e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(5.6306e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.3081e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.0147e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.5497e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(5.3531e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.5300e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(8.8402e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.2783e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(4.5729e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.3644e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.8841e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1921e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(4.2131e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.3016e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.9495e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.3511e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.5633e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.0862e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.8656e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.9407e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.7846e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.3181e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.6316e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.3842e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.1443e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.3083e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.7127e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1921e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.7166e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.8150e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(5.3108e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.3016e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.1393e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.3842e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(8.4754e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.4603e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.5965e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.4842e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.7010e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.9407e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.8766e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.6028e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(5.0247e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.2726e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.5538e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.4538e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.5500e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.0862e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.6129e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(7.5102e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(5.0379e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(9.2983e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.6889e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(9.5367e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.3884e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.8775e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.3869e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1474e-05, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.7010e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.3048e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.4104e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.6987e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.4166e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.3809e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(4.9033e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(6.9141e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.3038e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.0133e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.4341e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.7881e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.3855e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.6326e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.6027e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.5763e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(3.5726e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.4901e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.7969e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(4.0531e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.6209e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(3.9041e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.4492e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(8.3447e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(8.0615e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.5199e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.9782e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(2.4736e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.8891e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.3113e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.4356e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.3644e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.6279e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.4901e-06, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.5775e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(5.9605e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(4.8792e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.1921e-07, grad_fn=<MulBackward0>)
# Recon_loss = tensor(2.3831e-05, grad_fn=<MseLossBackward0>) and KLD_loss = tensor(1.4901e-07, grad_fn=<MulBackward0>)
